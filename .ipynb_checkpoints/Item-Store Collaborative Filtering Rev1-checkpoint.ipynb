# %%
import pandas as pd
import numpy as np

import seaborn as sns
import matplotlib.pyplot as plt

# %%
FILTER_DEPT = "FOODS_1" # Use only
ID_COLS = ['store_id', 'item_id'] # Columns to be considered in analysis
N_LAST_DAYS = 60 # Number of days for grouping sales

# %%
df = pd.read_csv("sales_train_evaluation.csv")

df.head()
# Out:
#          item_id    dept_id   cat_id store_id state_id  d_1  d_2  d_3  d_4  \
# 0  HOBBIES_1_001  HOBBIES_1  HOBBIES     CA_1       CA    0    0    0    0
# 1  HOBBIES_1_002  HOBBIES_1  HOBBIES     CA_1       CA    0    0    0    0
# 2  HOBBIES_1_003  HOBBIES_1  HOBBIES     CA_1       CA    0    0    0    0
# 3  HOBBIES_1_004  HOBBIES_1  HOBBIES     CA_1       CA    0    0    0    0
# 4  HOBBIES_1_005  HOBBIES_1  HOBBIES     CA_1       CA    0    0    0    0
#
#    d_5  ...  d_1932  d_1933  d_1934  d_1935  d_1936  d_1937  d_1938  d_1939  \
# 0    0  ...       2       4       0       0       0       0       3       3
# 1    0  ...       0       1       2       1       1       0       0       0
# 2    0  ...       1       0       2       0       0       0       2       3
# 3    0  ...       1       1       0       4       0       1       3       0
# 4    0  ...       0       0       0       2       1       0       0       2
#
#    d_1940  d_1941
# 0       0       1
# 1       0       0
# 2       0       1
# 3       2       6
# 4       1       0
#
# [5 rows x 1946 columns]

# %%
df.groupby('dept_id')['item_id'].nunique()
# Out:
# dept_id
# FOODS_1        216
# FOODS_2        398
# FOODS_3        823
# HOBBIES_1      416
# HOBBIES_2      149
# HOUSEHOLD_1    532
# HOUSEHOLD_2    515
# Name: item_id, dtype: int64

# %%
df_prep = df[df.dept_id == FILTER_DEPT]

df_prep = df_prep.set_index(ID_COLS)[df.columns[-N_LAST_DAYS:]].stack()

df_prep = df_prep.groupby(ID_COLS).sum().reset_index()

df_prep.columns = ID_COLS + ['sale_quantity']

df_prep.head()
# Out:
#   store_id      item_id  sale_quantity
# 0     CA_1  FOODS_1_001             58
# 1     CA_1  FOODS_1_002             33
# 2     CA_1  FOODS_1_003             44
# 3     CA_1  FOODS_1_004             95
# 4     CA_1  FOODS_1_005             81

# %% [markdown]
# ### Item-Store Collaborative Filtering

# %%
df_matrix = pd.pivot_table(df_prep, values='sale_quantity', index='store_id', columns='item_id')
df_matrix
# Out:
# item_id   FOODS_1_001  FOODS_1_002  FOODS_1_003  FOODS_1_004  FOODS_1_005  \
# store_id
# CA_1               58           33           44           95           81
# CA_2               52           43           76          193          322
# CA_3               65           38           60          190          178
# CA_4               16           13           19           66           78
# TX_1               29           11           16          269           50
# TX_2               22           12           38          255           85
# TX_3               28           19            3          393           79
# WI_1               30           54           70          249          149
# WI_2               35           22           13          723           95
# WI_3               17           12           14          337           79
#
# item_id   FOODS_1_006  FOODS_1_008  FOODS_1_009  FOODS_1_010  FOODS_1_011  \
# store_id
# CA_1              113           13           37           13           51
# CA_2               45           22           42           14          192
# CA_3               76            5           87           45          103
# CA_4               74           21           23           10           49
# TX_1               29            2           24           33           29
# TX_2               38            8            8           19           21
# TX_3               28           19            9           59           16
# WI_1               92           24           28          115           59
# WI_2               79            8           19           13           43
# WI_3               90            8           11           18           22
#
# item_id   ...  FOODS_1_210  FOODS_1_211  FOODS_1_212  FOODS_1_213  \
# store_id  ...
# CA_1      ...           79           14           31           47
# CA_2      ...          259           23           46           31
# CA_3      ...          195           20           37           40
# CA_4      ...           66           10            9           21
# TX_1      ...          115            2           23           23
# TX_2      ...          143            8           12            9
# TX_3      ...          130           37           10           10
# WI_1      ...           55           21           29           48
# WI_2      ...          216           26           12           20
# WI_3      ...           68           10           16           23
#
# item_id   FOODS_1_214  FOODS_1_215  FOODS_1_216  FOODS_1_217  FOODS_1_218  \
# store_id
# CA_1               60          108           35          178          574
# CA_2              137          433          131          492          576
# CA_3               76          305           83          454          563
# CA_4               29           75           26          107          441
# TX_1               17            3           46          159          618
# TX_2               20           94           62          140          754
# TX_3               19           32           50          160          871
# WI_1               41           80           47          144          551
# WI_2               32           57           62          124          799
# WI_3               22           46           52          126          723
#
# item_id   FOODS_1_219
# store_id
# CA_1              197
# CA_2              159
# CA_3              234
# CA_4               93
# TX_1              116
# TX_2              105
# TX_3               49
# WI_1              184
# WI_2              148
# WI_3              120
#
# [10 rows x 216 columns]

# %%
df_matrix_norm = df_matrix.apply(lambda x: (x-x.mean())/x.std(), axis = 0)

f, ax = plt.subplots(1,1, figsize=(18,5))

sns.heatmap(data=df_matrix_norm, ax=ax)
# Out:
# <AxesSubplot:xlabel='item_id', ylabel='store_id'>
